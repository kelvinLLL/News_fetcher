# %% [markdown]
# # This file will cost around 0.0006 * number(files) 元 When using qwen-turbo

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
import os
os.listdir("./drive/MyDrive/Proj/News_fetcher")
os.chdir("./drive/MyDrive/Proj/News_fetcher")
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Setup

# %%
# %pip install -q google-colab-selenium
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 51.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 499.2/499.2 kB 25.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 3.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# typeguard 4.4.3 requires typing_extensions>=4.14.0, but you have typing-extensions 4.13.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# ...

# %%
# !pip install trafilatura
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.6/132.6 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 837.9/837.9 kB 32.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.7/295.7 kB 20.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.7/274.7 kB 8.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Run

# %%
# !python tagging.py \
    --cleaned_file_name "index_contents.csv" \
    --model_name "qwen-turbo" \
    --prefix "/content/drive/MyDrive/Proj/News_fetcher/"
# Out:
# 🔑 Please enter your DashScope API key:
# [1/71] ✅ tagged & rated: input 488, output 11
# [2/71] ✅ tagged & rated: input 1753, output 20
# [3/71] ✅ tagged & rated: input 1150, output 15
# [4/71] ✅ tagged & rated: input 1426, output 11
# [5/71] ✅ tagged & rated: input 1290, output 17
# [6/71] ✅ tagged & rated: input 912, output 9
# [7/71] ✅ tagged & rated: input 1394, output 11
# [8/71] ✅ tagged & rated: input 4053, output 14
# [9/71] ✅ tagged & rated: input 488, output 11
# [10/71] ✅ tagged & rated: input 488, output 11
# [11/71] ✅ tagged & rated: input 1381, output 10
# [12/71] ✅ tagged & rated: input 1481, output 14
# [13/71] ✅ tagged & rated: input 1067, output 10
# [14/71] ✅ tagged & rated: input 1372, output 11
# [15/71] ✅ tagged & rated: input 1745, output 12
# [16/71] ✅ tagged & rated: input 983, output 10
# [17/71] ✅ tagged & rated: input 983, output 10
# [18/71] ✅ tagged & rated: input 841, output 14
# [19/71] ✅ tagged & rated: input 757, output 10
# ...

# %%
from data_collection_utilities import (
    # I/O
    save_lists_to_csv,
    load_csv
)
df = load_csv("tagged_index_contents.csv")
df
# Out:
#    index  ...                                                url
# 0      1  ...  https://www.cankaoxiaoxi.com/#/detailsPage/tt/...
# 1      2  ...  https://www.cankaoxiaoxi.com/#/detailsPage/tt/...
#
# [2 rows x 8 columns]
